# %%
import pandas as pd

# %%
Matches = pd.read_csv('matches.csv')
Deliveries = pd.read_csv('deliveries.csv')

# %% [markdown]
# # Q.1) Who will win the Match?

# %%
Matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
MI_vs_KXIP_matches = Matches[((Matches['team1']=='Mumbai Indians') & (Matches['team2']=='Kolkata Knight Riders') | (Matches['team2']=='Kolkata Knight Riders') & (Matches['team1']=='Mumbai Indians')) ]
MI_vs_KXIP_matches.head()
# Out:
#       id  season            city        date           team1  \
# 52    53    2017         Kolkata  2017-05-13  Mumbai Indians
# 131  132    2009  Port Elizabeth  2009-04-27  Mumbai Indians
# 137  138    2009     East London  2009-05-01  Mumbai Indians
# 229  230    2010         Kolkata  2010-04-19  Mumbai Indians
# 362  363    2012         Kolkata  2012-05-12  Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# 52   Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 131  Kolkata Knight Riders         Mumbai Indians           bat  normal
# 137  Kolkata Knight Riders         Mumbai Indians           bat  normal
# 229  Kolkata Knight Riders         Mumbai Indians           bat  normal
# 362  Kolkata Knight Riders         Mumbai Indians           bat  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# 52            0         Mumbai Indians            9               0
# ...

# %%
MI_win = 0
for i in MI_vs_KXIP_matches['winner']:
  if(i=='Mumbai Indians'):
    MI_win = MI_win + 1
MI_win
# Out:
# 8

# %%
MI_vs_KXIP_matches.shape
# Out:
# (11, 18)

# %%
KXIP_win = 0
for i in MI_vs_KXIP_matches['winner']:
  if(i=='Kolkata Knight Riders'):
    KXIP_win = KXIP_win + 1
KXIP_win
# Out:
# 3

# %%
MI_winning_percentage = (8/13)*100
MI_winning_percentage
# Out:
# 61.53846153846154

# %% [markdown]
# # Q.2) to what type of bowler Quinton de Kock out to?

# %%
Deliveries['batsman'].unique()
# Out:
# array(['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuvraj Singh',
#        'DJ Hooda', 'BCJ Cutting', 'CH Gayle', 'Mandeep Singh', 'TM Head',
#        'KM Jadhav', 'SR Watson', 'Sachin Baby', 'STR Binny', 'S Aravind',
#        'YS Chahal', 'TS Mills', 'A Choudhary', 'PA Patel', 'JC Buttler',
#        'RG Sharma', 'N Rana', 'AT Rayudu', 'KH Pandya', 'KA Pollard',
#        'HH Pandya', 'TG Southee', 'AM Rahane', 'MA Agarwal', 'SPD Smith',
#        'BA Stokes', 'MS Dhoni', 'JJ Roy', 'BB McCullum', 'SK Raina',
#        'AJ Finch', 'KD Karthik', 'G Gambhir', 'CA Lynn', 'MK Tiwary',
#        'DT Christian', 'HM Amla', 'M Vohra', 'WP Saha', 'AR Patel',
#        'GJ Maxwell', 'DA Miller', 'Vishnu Vinod', 'Iqbal Abdulla',
#        'P Negi', 'AP Tare', 'SW Billings', 'KK Nair', 'SV Samson',
#        'RR Pant', 'CH Morris', 'CR Brathwaite', 'PJ Cummins', 'A Mishra',
#        'S Nadeem', 'Z Khan', 'DR Smith', 'DS Kulkarni', 'P Kumar',
# ...

# %%
Quinton_Analysis = Deliveries[Deliveries['batsman'] == 'Q de Kock']
Quinton_Analysis.tail(60)
# Out:
#         match_id  inning    batting_team           bowling_team  over  ball  \
# 176795     11342       1  Mumbai Indians    Sunrisers Hyderabad    18     6
# 176796     11342       1  Mumbai Indians    Sunrisers Hyderabad    19     1
# 176798     11342       1  Mumbai Indians    Sunrisers Hyderabad    19     3
# 176799     11342       1  Mumbai Indians    Sunrisers Hyderabad    19     4
# 176803     11342       1  Mumbai Indians    Sunrisers Hyderabad    20     2
# 176805     11342       1  Mumbai Indians    Sunrisers Hyderabad    20     4
# 178002     11347       2  Mumbai Indians  Kolkata Knight Riders     1     1
# 178003     11347       2  Mumbai Indians  Kolkata Knight Riders     1     2
# 178004     11347       2  Mumbai Indians  Kolkata Knight Riders     1     3
# 178005     11347       2  Mumbai Indians  Kolkata Knight Riders     1     4
# 178006     11347       2  Mumbai Indians  Kolkata Knight Riders     1     5
# ...

# %%
Quinton_Analysis.shape
# Out:
# (1136, 21)

# %% [markdown]
# # Q.3) How many Wickets will KXIP lose in the powerplay?

# %%
KXIP_powerplay = Deliveries[Deliveries['batting_team'] == 'Kings XI Punjab']
KXIP_powerplay.head()
# Out:
#      match_id  inning     batting_team            bowling_team  over  ball  \
# 838         4       2  Kings XI Punjab  Rising Pune Supergiant     1     1
# 839         4       2  Kings XI Punjab  Rising Pune Supergiant     1     2
# 840         4       2  Kings XI Punjab  Rising Pune Supergiant     1     3
# 841         4       2  Kings XI Punjab  Rising Pune Supergiant     1     4
# 842         4       2  Kings XI Punjab  Rising Pune Supergiant     1     5
#
#      batsman non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 838  HM Amla     M Vohra  AB Dinda              0  ...         0            0
# 839  HM Amla     M Vohra  AB Dinda              0  ...         0            0
# 840  HM Amla     M Vohra  AB Dinda              0  ...         0            0
# 841  HM Amla     M Vohra  AB Dinda              0  ...         0            0
# 842  M Vohra     HM Amla  AB Dinda              0  ...         0            0
#
# ...

# %%
KXIP_powerplay = Deliveries[Deliveries['over'] <= 6]
KXIP_powerplay.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
wickets = KXIP_powerplay['player_dismissed'].count()
wickets
# Out:
# 2177

# %%
wickets_in_powerplay_per_match = wickets/KXIP_powerplay['match_id'].nunique()
wickets_in_powerplay_per_match
# Out:
# 2.8796296296296298

# %% [markdown]
# # Q.4) How will KL Rahul get out?

# %%
Deliveries['batsman'].unique()
# Out:
# array(['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuvraj Singh',
#        'DJ Hooda', 'BCJ Cutting', 'CH Gayle', 'Mandeep Singh', 'TM Head',
#        'KM Jadhav', 'SR Watson', 'Sachin Baby', 'STR Binny', 'S Aravind',
#        'YS Chahal', 'TS Mills', 'A Choudhary', 'PA Patel', 'JC Buttler',
#        'RG Sharma', 'N Rana', 'AT Rayudu', 'KH Pandya', 'KA Pollard',
#        'HH Pandya', 'TG Southee', 'AM Rahane', 'MA Agarwal', 'SPD Smith',
#        'BA Stokes', 'MS Dhoni', 'JJ Roy', 'BB McCullum', 'SK Raina',
#        'AJ Finch', 'KD Karthik', 'G Gambhir', 'CA Lynn', 'MK Tiwary',
#        'DT Christian', 'HM Amla', 'M Vohra', 'WP Saha', 'AR Patel',
#        'GJ Maxwell', 'DA Miller', 'Vishnu Vinod', 'Iqbal Abdulla',
#        'P Negi', 'AP Tare', 'SW Billings', 'KK Nair', 'SV Samson',
#        'RR Pant', 'CH Morris', 'CR Brathwaite', 'PJ Cummins', 'A Mishra',
#        'S Nadeem', 'Z Khan', 'DR Smith', 'DS Kulkarni', 'P Kumar',
# ...

# %%
Rahul_Analysis = Deliveries[Deliveries['batsman'] == 'KL Rahul']
Rahul_Analysis.tail(60)
# Out:
#         match_id  inning     batting_team           bowling_team  over  ball  \
# 176377     11339       2  Kings XI Punjab    Sunrisers Hyderabad    15     4
# 176378     11339       2  Kings XI Punjab    Sunrisers Hyderabad    15     5
# 176380     11339       2  Kings XI Punjab    Sunrisers Hyderabad    16     1
# 176381     11339       2  Kings XI Punjab    Sunrisers Hyderabad    16     2
# 176382     11339       2  Kings XI Punjab    Sunrisers Hyderabad    16     3
# 176383     11339       2  Kings XI Punjab    Sunrisers Hyderabad    16     4
# 176384     11339       2  Kings XI Punjab    Sunrisers Hyderabad    16     5
# 176385     11339       2  Kings XI Punjab    Sunrisers Hyderabad    16     6
# 176388     11339       2  Kings XI Punjab    Sunrisers Hyderabad    17     3
# 176389     11339       2  Kings XI Punjab    Sunrisers Hyderabad    17     4
# 176391     11339       2  Kings XI Punjab    Sunrisers Hyderabad    17     6
# ...

# %%
Rahul_caught = Rahul_Analysis[Rahul_Analysis['dismissal_kind'] == 'caught']
Rahul_caught['dismissal_kind'].count()
# Out:
# 30

# %%
Rahul_lbw = Rahul_Analysis[Rahul_Analysis['dismissal_kind'] == 'lbw']
Rahul_lbw['dismissal_kind'].count()
# Out:
# 4

# %%
Rahul_bowled = Rahul_Analysis[Rahul_Analysis['dismissal_kind'] == 'bowled']
Rahul_bowled['dismissal_kind'].count()
# Out:
# 10

# %%
Rahul_runout = Rahul_Analysis[Rahul_Analysis['dismissal_kind'] == 'run out']
Rahul_runout['dismissal_kind'].count()
# Out:
# 3

# %%
caught_out_percentage = (30/47)*100
caught_out_percentage
# Out:
# 63.829787234042556

# %% [markdown]
# # Q.5) How many wickets will fall in total during the match?

# %%
MI_vs_KXIP_matches = Deliveries[((Deliveries['batting_team']=='Mumbai Indians') & (Deliveries['bowling_team']=='Kolkata Knight Riders') | (Deliveries['batting_team']=='Kolkata Knight Riders') & (Deliveries['bowling_team']=='Mumbai Indians')) ]
MI_vs_KXIP_matches.head()
# Out:
#       match_id  inning           batting_team    bowling_team  over  ball  \
# 1424         7       1  Kolkata Knight Riders  Mumbai Indians     1     1
# 1425         7       1  Kolkata Knight Riders  Mumbai Indians     1     2
# 1426         7       1  Kolkata Knight Riders  Mumbai Indians     1     3
# 1427         7       1  Kolkata Knight Riders  Mumbai Indians     1     4
# 1428         7       1  Kolkata Knight Riders  Mumbai Indians     1     5
#
#         batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 1424  G Gambhir     CA Lynn  SL Malinga              0  ...         0
# 1425    CA Lynn   G Gambhir  SL Malinga              0  ...         0
# 1426    CA Lynn   G Gambhir  SL Malinga              0  ...         0
# 1427  G Gambhir     CA Lynn  SL Malinga              0  ...         0
# 1428  G Gambhir     CA Lynn  SL Malinga              0  ...         0
#
#       legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
MI_vs_KXIP_matches['player_dismissed'].count()
# Out:
# 278

# %%
wickets_per_match = 278/MI_vs_KXIP_matches['match_id'].nunique()
wickets_per_match
# Out:
# 11.12
