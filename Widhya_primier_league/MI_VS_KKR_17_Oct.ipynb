# %% [markdown]
# # Mumbai Vs KKR 17_Oct

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading the Data

# %%
Matches = pd.read_csv('matches.csv')
Deliveries = pd.read_csv('deliveries.csv')

# %%
Matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
Deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
Deliveries['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
Mumbai_Batting = Deliveries[Deliveries['batting_team'] == 'Mumbai Indians']
Mumbai_Batting.tail(330)
# Out:
#         match_id  inning    batting_team           bowling_team  over  ball  \
# 178009     11347       2  Mumbai Indians  Kolkata Knight Riders     2     2
# 178010     11347       2  Mumbai Indians  Kolkata Knight Riders     2     3
# 178011     11347       2  Mumbai Indians  Kolkata Knight Riders     2     4
# 178012     11347       2  Mumbai Indians  Kolkata Knight Riders     2     5
# 178013     11347       2  Mumbai Indians  Kolkata Knight Riders     2     6
# ...          ...     ...             ...                    ...   ...   ...
# 178949     11415       1  Mumbai Indians    Chennai Super Kings    20     2
# 178950     11415       1  Mumbai Indians    Chennai Super Kings    20     3
# 178951     11415       1  Mumbai Indians    Chennai Super Kings    20     4
# 178952     11415       1  Mumbai Indians    Chennai Super Kings    20     5
# 178953     11415       1  Mumbai Indians    Chennai Super Kings    20     6
#
# ...

# %% [markdown]
# # Q.2) Number of Wickets MI Lose in overs 6-15

# %%
MI_wickets = Mumbai_Batting[(Mumbai_Batting['over'] == 6) | (Mumbai_Batting['over'] == 7) | (Mumbai_Batting['over'] == 8) | (Mumbai_Batting['over'] == 9) | (Mumbai_Batting['over'] == 10) | (Mumbai_Batting['over'] == 11) | (Mumbai_Batting['over'] == 12) | (Mumbai_Batting['over'] == 13) | (Mumbai_Batting['over'] == 14) | (Mumbai_Batting['over'] == 15) | (Mumbai_Batting['over'] == 16)]
MI_wickets.shape
# Out:
# (12557, 21)

# %%
MI_wickets.head()
# Out:
#      match_id  inning    batting_team            bowling_team  over  ball  \
# 279         2       1  Mumbai Indians  Rising Pune Supergiant     6     1
# 280         2       1  Mumbai Indians  Rising Pune Supergiant     6     2
# 281         2       1  Mumbai Indians  Rising Pune Supergiant     6     3
# 282         2       1  Mumbai Indians  Rising Pune Supergiant     6     4
# 283         2       1  Mumbai Indians  Rising Pune Supergiant     6     5
#
#         batsman non_striker     bowler  is_super_over  ...  bye_runs  \
# 279   RG Sharma  JC Buttler  DL Chahar              0  ...         0
# 280  JC Buttler   RG Sharma  DL Chahar              0  ...         0
# 281  JC Buttler   RG Sharma  DL Chahar              0  ...         0
# 282  JC Buttler   RG Sharma  DL Chahar              0  ...         0
# 283  JC Buttler   RG Sharma  DL Chahar              0  ...         0
#
#      legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
total_wickets =  MI_wickets['player_dismissed'].count()
total_wickets
# Out:
# 541

# %%
MI_wickets['match_id'].nunique()
# Out:
# 187

# %%
avg_wickets = total_wickets / MI_wickets['match_id'].nunique()
avg_wickets
# Out:
# 2.893048128342246

# %% [markdown]
# # Mumbai Bowling Analysis

# %%
Mumbai_bowl = Deliveries[Deliveries['bowling_team']=='Mumbai Indians']
Mumbai_bowl.head(120)
# Out:
#      match_id  inning            batting_team    bowling_team  over  ball  \
# 373         2       2  Rising Pune Supergiant  Mumbai Indians     1     1
# 374         2       2  Rising Pune Supergiant  Mumbai Indians     1     2
# 375         2       2  Rising Pune Supergiant  Mumbai Indians     1     3
# 376         2       2  Rising Pune Supergiant  Mumbai Indians     1     4
# 377         2       2  Rising Pune Supergiant  Mumbai Indians     1     5
# ..        ...     ...                     ...             ...   ...   ...
# 488         2       2  Rising Pune Supergiant  Mumbai Indians    19     5
# 489         2       2  Rising Pune Supergiant  Mumbai Indians    19     6
# 490         2       2  Rising Pune Supergiant  Mumbai Indians    20     1
# 491         2       2  Rising Pune Supergiant  Mumbai Indians    20     2
# 492         2       2  Rising Pune Supergiant  Mumbai Indians    20     3
#
#         batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# ...

# %% [markdown]
# # KKR batting

# %%
KKR_batting = Deliveries[Deliveries['batting_team'] == 'Kolkata Knight Riders']
KKR_batting.head()
# Out:
#      match_id  inning           batting_team   bowling_team  over  ball  \
# 617         3       2  Kolkata Knight Riders  Gujarat Lions     1     1
# 618         3       2  Kolkata Knight Riders  Gujarat Lions     1     2
# 619         3       2  Kolkata Knight Riders  Gujarat Lions     1     3
# 620         3       2  Kolkata Knight Riders  Gujarat Lions     1     4
# 621         3       2  Kolkata Knight Riders  Gujarat Lions     1     5
#
#        batsman non_striker   bowler  is_super_over  ...  bye_runs  \
# 617  G Gambhir     CA Lynn  P Kumar              0  ...         0
# 618    CA Lynn   G Gambhir  P Kumar              0  ...         0
# 619    CA Lynn   G Gambhir  P Kumar              0  ...         0
# 620  G Gambhir     CA Lynn  P Kumar              0  ...         0
# 621  G Gambhir     CA Lynn  P Kumar              0  ...         0
#
#      legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# # Q.3) Fours Hit By KKR in the Match

# %%
KKR_four = 0
for i in KKR_batting['batsman_runs']:
    if(i == 4):
        KKR_four = KKR_four +1
KKR_four
# Out:
# 2434

# %%
KKR_avg_four = KKR_four/KKR_batting['match_id'].nunique()
KKR_avg_four
# Out:
# 13.674157303370787

# %% [markdown]
# # KKR Bowling

# %%
KKR_bowl = Deliveries[Deliveries['bowling_team'] == 'Kolkata Knight Riders']
KKR_bowl
# Out:
#         match_id  inning    batting_team           bowling_team  over  ball  \
# 495            3       1   Gujarat Lions  Kolkata Knight Riders     1     1
# 496            3       1   Gujarat Lions  Kolkata Knight Riders     1     2
# 497            3       1   Gujarat Lions  Kolkata Knight Riders     1     3
# 498            3       1   Gujarat Lions  Kolkata Knight Riders     1     4
# 499            3       1   Gujarat Lions  Kolkata Knight Riders     1     5
# ...          ...     ...             ...                    ...   ...   ...
# 178097     11347       2  Mumbai Indians  Kolkata Knight Riders    16     3
# 178098     11347       2  Mumbai Indians  Kolkata Knight Riders    16     4
# 178099     11347       2  Mumbai Indians  Kolkata Knight Riders    16     5
# 178100     11347       2  Mumbai Indians  Kolkata Knight Riders    16     6
# 178101     11347       2  Mumbai Indians  Kolkata Knight Riders    17     1
#
# ...

# %%
KKR_bowl.shape
# Out:
# (20940, 21)

# %% [markdown]
# # Team Clash Analysis

# %%
MI_vs_KXIP_matches = Matches[((Matches['team1']=='Mumbai Indians') & (Matches['team2']=='Kolkata Knight Riders') | (Matches['team2']=='Kolkata Knight Riders') & (Matches['team1']=='Mumbai Indians')) ]
MI_vs_KXIP_matches.head()
# Out:
#       id  season            city        date           team1  \
# 52    53    2017         Kolkata  2017-05-13  Mumbai Indians
# 131  132    2009  Port Elizabeth  2009-04-27  Mumbai Indians
# 137  138    2009     East London  2009-05-01  Mumbai Indians
# 229  230    2010         Kolkata  2010-04-19  Mumbai Indians
# 362  363    2012         Kolkata  2012-05-12  Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# 52   Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 131  Kolkata Knight Riders         Mumbai Indians           bat  normal
# 137  Kolkata Knight Riders         Mumbai Indians           bat  normal
# 229  Kolkata Knight Riders         Mumbai Indians           bat  normal
# 362  Kolkata Knight Riders         Mumbai Indians           bat  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# 52            0         Mumbai Indians            9               0
# ...

# %%
MI_vs_KXIP_scores = Deliveries[((Deliveries['batting_team']=='Mumbai Indians') & (Deliveries['bowling_team']=='Kolkata Knight Riders') | (Deliveries['batting_team']=='Kolkata Knight Riders') & (Deliveries['bowling_team']=='Mumbai Indians')) ]
MI_vs_KXIP_scores.head()
# Out:
#       match_id  inning           batting_team    bowling_team  over  ball  \
# 1424         7       1  Kolkata Knight Riders  Mumbai Indians     1     1
# 1425         7       1  Kolkata Knight Riders  Mumbai Indians     1     2
# 1426         7       1  Kolkata Knight Riders  Mumbai Indians     1     3
# 1427         7       1  Kolkata Knight Riders  Mumbai Indians     1     4
# 1428         7       1  Kolkata Knight Riders  Mumbai Indians     1     5
#
#         batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 1424  G Gambhir     CA Lynn  SL Malinga              0  ...         0
# 1425    CA Lynn   G Gambhir  SL Malinga              0  ...         0
# 1426    CA Lynn   G Gambhir  SL Malinga              0  ...         0
# 1427  G Gambhir     CA Lynn  SL Malinga              0  ...         0
# 1428  G Gambhir     CA Lynn  SL Malinga              0  ...         0
#
#       legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
MI_vs_KXIP_scores.shape
# Out:
# (5903, 21)

# %% [markdown]
# # Q.4) Runs scored in the Match

# %%
Total_runs =0
for i in MI_vs_KXIP_scores['total_runs']:
    if(i !=0):
        Total_runs = Total_runs + i
Total_runs
# Out:
# 7685

# %%
Avg_run_scored = Total_runs/MI_vs_KXIP_scores['match_id'].nunique()
Avg_run_scored
# Out:
# 307.4

# %% [markdown]
# # Q.1) Who will Win?

# %%
MI_win = 0
for i in MI_vs_KXIP_matches['winner']:
  if(i=='Mumbai Indians'):
    MI_win = MI_win + 1
MI_win
# Out:
# 8

# %%
KKR_win = 0
for i in MI_vs_KXIP_matches['winner']:
  if(i=='Kolkata Knight Riders'):
    KKR_win = KKR_win + 1
KKR_win
# Out:
# 3

# %%
MI_winning_percentage = (8/13)*100
MI_winning_percentage
# Out:
# 61.53846153846154

# %% [markdown]
# # Q.5) How Rohit Sharma will get OUT?

# %%
Rohit_Analysis = Deliveries[Deliveries['batsman'] == 'RG Sharma']
Rohit_Analysis.tail(60)
# Out:
#         match_id  inning    batting_team           bowling_team  over  ball  \
# 178014     11347       2  Mumbai Indians  Kolkata Knight Riders     2     7
# 178017     11347       2  Mumbai Indians  Kolkata Knight Riders     3     3
# 178018     11347       2  Mumbai Indians  Kolkata Knight Riders     3     4
# 178020     11347       2  Mumbai Indians  Kolkata Knight Riders     3     6
# 178021     11347       2  Mumbai Indians  Kolkata Knight Riders     3     7
# 178022     11347       2  Mumbai Indians  Kolkata Knight Riders     4     1
# 178023     11347       2  Mumbai Indians  Kolkata Knight Riders     4     2
# 178028     11347       2  Mumbai Indians  Kolkata Knight Riders     5     1
# 178029     11347       2  Mumbai Indians  Kolkata Knight Riders     5     2
# 178032     11347       2  Mumbai Indians  Kolkata Knight Riders     5     5
# 178033     11347       2  Mumbai Indians  Kolkata Knight Riders     5     6
# ...

# %%
Rohit_Analysis.shape
# Out:
# (3816, 21)

# %%
Rohit_caught = Rohit_Analysis[Rohit_Analysis['dismissal_kind'] == 'caught']
Rohit_caught['dismissal_kind'].count()
# Out:
# 103

# %%
Rohit_lbw = Rohit_Analysis[Rohit_Analysis['dismissal_kind'] == 'lbw']
Rohit_lbw['dismissal_kind'].count()
# Out:
# 11

# %%
Rohit_bowled = Rohit_Analysis[Rohit_Analysis['dismissal_kind'] == 'bowled']
Rohit_bowled['dismissal_kind'].count()
# Out:
# 22

# %%
Rohit_runout = Rohit_Analysis[Rohit_Analysis['dismissal_kind'] == 'run out']
Rohit_runout['dismissal_kind'].count()
# Out:
# 17
